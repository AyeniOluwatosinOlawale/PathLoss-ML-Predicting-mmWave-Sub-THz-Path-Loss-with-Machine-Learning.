# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib
import seaborn as sns
from matplotlib.pyplot import figure

# %%
#loading the data
data = pd.read_excel('Umascenario.xlsx')

# %%
data
# Out:
#        Simulation run number  T-R Separation Distance (m)  . Time Delay (ns)  \
# 0                          1                    57.977539         193.258462
# 1                          1                    57.977539         193.472333
# 2                          1                    57.977539         195.109122
# 3                          1                    57.977539         233.076020
# 4                          1                    57.977539         249.558287
# ...                      ...                          ...                ...
# 40794                     40                    47.742760        1421.327425
# 40795                     40                    47.742760        1435.500507
# 40796                     40                    47.742760        1450.080342
# 40797                     40                    47.742760        1466.773721
# 40798                     40                    47.742760        1483.963383
#
#        Received Power (dBm)  Phase (rad)  Azimuth AoD (degree)  \
# 0                -68.257511     3.759055             78.283021
# 1                -72.508549     1.060502             70.486281
# 2                -71.977249     1.213320             71.359102
# 3                -70.013310     1.942194             73.554387
# 4                -73.446414     1.272149             73.330504
# ...                     ...          ...                   ...
# 40794           -160.000000     5.690095            359.578816
# 40795           -160.000000     0.600962             69.268146
# 40796           -160.000000     0.802098             45.586570
# 40797           -160.000000     3.194196             50.811735
# 40798           -160.000000     2.181907              7.705468
#
#        Elevation AoD (degree)  Azimuth AoA (degree)  Elevation AoA (degree)  \
# 0                   -3.751318            199.049784                0.097891
# 1                   -6.505634             87.494410                1.970377
# 2                   -4.490295            208.866147                0.097891
# 3                    0.463410            213.825480                0.097891
# 4                    0.246960            219.833014                0.097891
# ...                       ...                   ...                     ...
# 40794               -6.060897             11.036271                2.525915
# 40795               -6.482829              6.185082                6.683232
# 40796               -3.238030            354.705272               14.195423
# 40797               -6.950233              4.772978                9.275438
# 40798               -5.575499            358.075392                8.372237
#
#        Path Loss (dB)  RMS Delay Spread (ns)  frequency
# 0           96.985871              29.355245    142.000
# 1          102.498544               1.694574    142.000
# 2          100.436539              18.012473    142.000
# 3           98.838450              13.741473    142.000
# 4          100.810359               9.841253    142.000
# ...               ...                    ...        ...
# 40794      141.116324              74.295517      7.125
# 40795      144.979239              50.242149      7.125
# 40796      122.114161              12.791678      7.125
# 40797      130.681302              36.002964      7.125
# 40798      132.627374              69.931803      7.125
#
# [40799 rows x 12 columns]

# %%
data.dtypes
# Out:
# Simulation run number            int64
# T-R Separation Distance (m)    float64
# . Time Delay (ns)              float64
# Received Power (dBm)           float64
# Phase (rad)                    float64
# Azimuth AoD (degree)           float64
# Elevation AoD (degree)         float64
# Azimuth AoA (degree)           float64
# Elevation AoA (degree)         float64
# Path Loss (dB)                 float64
# RMS Delay Spread (ns)          float64
# frequency                      float64
# dtype: object

# %%
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40799 entries, 0 to 40798
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Simulation run number        40799 non-null  int64
#  1   T-R Separation Distance (m)  40799 non-null  float64
#  2   . Time Delay (ns)            40799 non-null  float64
#  3   Received Power (dBm)         40799 non-null  float64
#  4   Phase (rad)                  40799 non-null  float64
#  5   Azimuth AoD (degree)         40799 non-null  float64
#  6   Elevation AoD (degree)       40799 non-null  float64
#  7   Azimuth AoA (degree)         40799 non-null  float64
#  8   Elevation AoA (degree)       40799 non-null  float64
#  9   Path Loss (dB)               40799 non-null  float64
#  10  RMS Delay Spread (ns)        40799 non-null  float64
#  11  frequency                    40799 non-null  float64
# dtypes: float64(11), int64(1)
# memory usage: 3.7 MB
#        Simulation run number  T-R Separation Distance (m)  . Time Delay (ns)  \
# count           40799.000000                 40799.000000       40799.000000
# mean               21.193583                    48.616856         473.199655
# std                11.491985                    12.687668         329.204188
# min                 1.000000                    33.504552         112.803075
# 25%                11.000000                    38.049196         224.242157
# 50%                22.000000                    44.166532         368.025487
# 75%                31.000000                    57.667848         621.308718
# max                40.000000                    92.386646        1698.116579
#
#        Received Power (dBm)   Phase (rad)  Azimuth AoD (degree)  \
# count          40799.000000  40799.000000          40799.000000
# mean            -118.043589      3.111973            182.433757
# std               27.313443      1.805462            105.663569
# min             -160.000000      0.000046              0.000872
# 25%             -140.080493      1.549134             85.123350
# 50%             -114.980750      3.077443            197.429021
# 75%              -98.315773      4.658706            258.292986
# max              -33.852707      6.282862            359.999653
#
#        Elevation AoD (degree)  Azimuth AoA (degree)  Elevation AoA (degree)  \
# count            40799.000000          40799.000000            40799.000000
# mean                -4.373335            189.303059                4.070531
# std                  5.422049             99.102440                6.691963
# min                -43.938712              0.001571              -43.726285
# 25%                 -7.481974            103.501449                0.185554
# 50%                 -3.931197            197.130837                3.600372
# 75%                 -0.935624            275.509700                7.449757
# max                 23.326663            359.992574               62.009606
#
#        Path Loss (dB)  RMS Delay Spread (ns)     frequency
# count    40799.000000           40799.000000  40799.000000
# mean       129.421653              43.935158     47.646387
# std         17.764116              45.505637     38.008109
# min         63.849834               0.000888      7.125000
# 25%        117.985163              13.361640      7.125000
# 50%        129.657802              31.662950     28.000000
# 75%        140.683909              58.749292     95.000000
# max        188.699492             603.057700    142.000000

# %%
data.isnull().any()
# Out:
# Simulation run number          False
# T-R Separation Distance (m)    False
# . Time Delay (ns)              False
# Received Power (dBm)           False
# Phase (rad)                    False
# Azimuth AoD (degree)           False
# Elevation AoD (degree)         False
# Azimuth AoA (degree)           False
# Elevation AoA (degree)         False
# Path Loss (dB)                 False
# RMS Delay Spread (ns)          False
# frequency                      False
# dtype: bool

# %%
correlation_matrix = data.corr()
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation of features in the dataset for Uma Scenario ')

# Saving the figure as a JPEG file
output_file_path1 = 'output_figure1.jpg'
plt.savefig(output_file_path1, format='jpeg')


plt.show()

# %% [markdown]
# # Exploratory Data Analysis

# %%
fig = plt.figure(figsize = (15,20))
ax = fig.gca()
data.hist(ax = ax, bins = 10)


# Saving the figure as a JPEG file
output_file_path = 'output_figure.jpg'
plt.savefig(output_file_path, format='jpeg')


fig.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_17232\2899571983.py:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   data.hist(ax = ax, bins = 10)
# C:\Users\User\AppData\Local\Temp\ipykernel_17232\2899571983.py:11: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
def feature_plotting(feature_name, target):

  colour = np.random.rand(3,)

  print('Summary stats for {}:\n'.format(feature_name) )
  print(data[feature_name].describe())
  plt.show()
  print('\nBoxplot will show us spread and highlight outliers:\n')
  sns.boxplot(x = data [feature_name], color = colour)
  plt.show()
  print('\nScatterplot will show us relationship between {} and {}:\n'.format(feature_name, target))
  sns.scatterplot(data=data,x = data[feature_name], y = data[target], color = colour)
  plt.show()

# %%
feature_plotting ('T-R Separation Distance (m)', 'Path Loss (dB)')
# Out:
# Summary stats for T-R Separation Distance (m):
#
# count    40799.000000
# mean        48.616856
# std         12.687668
# min         33.504552
# 25%         38.049196
# 50%         44.166532
# 75%         57.667848
# max         92.386646
# Name: T-R Separation Distance (m), dtype: float64
#
# Boxplot will show us spread and highlight outliers:
# Scatterplot will show us relationship between T-R Separation Distance (m) and Path Loss (dB):

# %%
feature_plotting ('frequency', 'Path Loss (dB)')
# Out:
# Summary stats for frequency:
#
# count    40799.000000
# mean        47.646387
# std         38.008109
# min          7.125000
# 25%          7.125000
# 50%         28.000000
# 75%         95.000000
# max        142.000000
# Name: frequency, dtype: float64
#
# Boxplot will show us spread and highlight outliers:
# Scatterplot will show us relationship between frequency and Path Loss (dB):

# %%
feature_plotting ('RMS Delay Spread (ns)', 'Path Loss (dB)')
# Out:
# Summary stats for RMS Delay Spread (ns):
#
# count    40799.000000
# mean        43.935158
# std         45.505637
# min          0.000888
# 25%         13.361640
# 50%         31.662950
# 75%         58.749292
# max        603.057700
# Name: RMS Delay Spread (ns), dtype: float64
#
# Boxplot will show us spread and highlight outliers:
# Scatterplot will show us relationship between RMS Delay Spread (ns) and Path Loss (dB):

# %%
data['Path Loss (dB)'].describe()
sns.violinplot(x = data ['Path Loss (dB)'])
# Out:
# <AxesSubplot:xlabel='Path Loss (dB)'>

# %% [markdown]
# # Creating a Synthetic Feature with the Original data

# %%
data['Path/T-R distance(dB/m)'] = data['Path Loss (dB)'] / data['T-R Separation Distance (m)']

# %%
data
# Out:
#        Simulation run number  T-R Separation Distance (m)  . Time Delay (ns)  \
# 0                          1                    57.977539         193.258462
# 1                          1                    57.977539         193.472333
# 2                          1                    57.977539         195.109122
# 3                          1                    57.977539         233.076020
# 4                          1                    57.977539         249.558287
# ...                      ...                          ...                ...
# 40794                     40                    47.742760        1421.327425
# 40795                     40                    47.742760        1435.500507
# 40796                     40                    47.742760        1450.080342
# 40797                     40                    47.742760        1466.773721
# 40798                     40                    47.742760        1483.963383
#
#        Received Power (dBm)  Phase (rad)  Azimuth AoD (degree)  \
# 0                -68.257511     3.759055             78.283021
# 1                -72.508549     1.060502             70.486281
# 2                -71.977249     1.213320             71.359102
# 3                -70.013310     1.942194             73.554387
# 4                -73.446414     1.272149             73.330504
# ...                     ...          ...                   ...
# 40794           -160.000000     5.690095            359.578816
# 40795           -160.000000     0.600962             69.268146
# 40796           -160.000000     0.802098             45.586570
# 40797           -160.000000     3.194196             50.811735
# 40798           -160.000000     2.181907              7.705468
#
#        Elevation AoD (degree)  Azimuth AoA (degree)  Elevation AoA (degree)  \
# 0                   -3.751318            199.049784                0.097891
# 1                   -6.505634             87.494410                1.970377
# 2                   -4.490295            208.866147                0.097891
# 3                    0.463410            213.825480                0.097891
# 4                    0.246960            219.833014                0.097891
# ...                       ...                   ...                     ...
# 40794               -6.060897             11.036271                2.525915
# 40795               -6.482829              6.185082                6.683232
# 40796               -3.238030            354.705272               14.195423
# 40797               -6.950233              4.772978                9.275438
# 40798               -5.575499            358.075392                8.372237
#
#        Path Loss (dB)  RMS Delay Spread (ns)  frequency  \
# 0           96.985871              29.355245    142.000
# 1          102.498544               1.694574    142.000
# 2          100.436539              18.012473    142.000
# 3           98.838450              13.741473    142.000
# 4          100.810359               9.841253    142.000
# ...               ...                    ...        ...
# 40794      141.116324              74.295517      7.125
# 40795      144.979239              50.242149      7.125
# 40796      122.114161              12.791678      7.125
# 40797      130.681302              36.002964      7.125
# 40798      132.627374              69.931803      7.125
#
#        Path/T-R distance(dB/m)
# 0                     1.672818
# 1                     1.767901
# 2                     1.732335
# 3                     1.704771
# 4                     1.738783
# ...                        ...
# 40794                 2.955764
# 40795                 3.036675
# 40796                 2.557752
# 40797                 2.737196
# 40798                 2.777958
#
# [40799 rows x 13 columns]

# %% [markdown]
# # Data Pre-Processing

# %%
data = data.drop('Simulation run number', axis= 1)

# %%
data
# Out:
#        T-R Separation Distance (m)  . Time Delay (ns)  Received Power (dBm)  \
# 0                        57.977539         193.258462            -68.257511
# 1                        57.977539         193.472333            -72.508549
# 2                        57.977539         195.109122            -71.977249
# 3                        57.977539         233.076020            -70.013310
# 4                        57.977539         249.558287            -73.446414
# ...                            ...                ...                   ...
# 40794                    47.742760        1421.327425           -160.000000
# 40795                    47.742760        1435.500507           -160.000000
# 40796                    47.742760        1450.080342           -160.000000
# 40797                    47.742760        1466.773721           -160.000000
# 40798                    47.742760        1483.963383           -160.000000
#
#        Phase (rad)  Azimuth AoD (degree)  Elevation AoD (degree)  \
# 0         3.759055             78.283021               -3.751318
# 1         1.060502             70.486281               -6.505634
# 2         1.213320             71.359102               -4.490295
# 3         1.942194             73.554387                0.463410
# 4         1.272149             73.330504                0.246960
# ...            ...                   ...                     ...
# 40794     5.690095            359.578816               -6.060897
# 40795     0.600962             69.268146               -6.482829
# 40796     0.802098             45.586570               -3.238030
# 40797     3.194196             50.811735               -6.950233
# 40798     2.181907              7.705468               -5.575499
#
#        Azimuth AoA (degree)  Elevation AoA (degree)  Path Loss (dB)  \
# 0                199.049784                0.097891       96.985871
# 1                 87.494410                1.970377      102.498544
# 2                208.866147                0.097891      100.436539
# 3                213.825480                0.097891       98.838450
# 4                219.833014                0.097891      100.810359
# ...                     ...                     ...             ...
# 40794             11.036271                2.525915      141.116324
# 40795              6.185082                6.683232      144.979239
# 40796            354.705272               14.195423      122.114161
# 40797              4.772978                9.275438      130.681302
# 40798            358.075392                8.372237      132.627374
#
#        RMS Delay Spread (ns)  frequency  Path/T-R distance(dB/m)
# 0                  29.355245    142.000                 1.672818
# 1                   1.694574    142.000                 1.767901
# 2                  18.012473    142.000                 1.732335
# 3                  13.741473    142.000                 1.704771
# 4                   9.841253    142.000                 1.738783
# ...                      ...        ...                      ...
# 40794              74.295517      7.125                 2.955764
# 40795              50.242149      7.125                 3.036675
# 40796              12.791678      7.125                 2.557752
# 40797              36.002964      7.125                 2.737196
# 40798              69.931803      7.125                 2.777958
#
# [40799 rows x 12 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor
from xgboost import XGBRegressor
from sklearn.preprocessing import FunctionTransformer
from sklearn.compose import TransformedTargetRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import learning_curve
import time
from sklearn.preprocessing import MinMaxScaler
from sklearn.dummy import DummyRegressor
import xgboost as xgb
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint, uniform
from sklearn.tree import DecisionTreeRegressor
import os
from keras.models import Sequential
from keras.layers import Dense

# %%
X = data.loc[:,data.columns != 'Path Loss (dB)']
y = data.loc[:,'Path Loss (dB)']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=18)

# %% [markdown]
# # Modelling and Evaluation of the peformance of the models

# %%
#Creating a baseline Model

dummy_regressor = DummyRegressor(strategy='mean')  
dummy_regressor.fit(X_train, y_train)

# Making predictions using the dummy regressor
y_pred = dummy_regressor.predict(X_test)

# %%
#Dummy regressor Evaluation
mse_5 = mean_squared_error(y_test, y_pred)
rmse_5 = np.sqrt(mse_5)
r2_5 = r2_score(y_test, y_pred)
mae_5 = mean_absolute_error(y_test, y_pred)
print("dummy_regressor MAE:", mae_5)
print("dummy_regressor R-squared:", r2_5)
print("dummy_regressor RMSE:", rmse_5)
print("dummy_regressor MSE:", mse_5)
# Out:
# dummy_regressor MAE: 13.801201133050693
# dummy_regressor R-squared: -5.5574015694670464e-05
# dummy_regressor RMSE: 17.566792174603503
# dummy_regressor MSE: 308.59218730571087

# %%
# Setting the random seed for reproducibility
random_seed = 42
np.random.seed(random_seed)

# Defining the parameter grid
param_grid = {
    'max_depth': randint(3, 10),  # Random integer values between 3 and 10
    'learning_rate': uniform(0.01, 0.3),  # Random float values between 0.01 and 0.3
    'n_estimators': randint(100, 1000),  # Random integer values between 100 and 1000
    'subsample': uniform(0.6, 0.4),  # Random float values between 0.6 and 1.0
    'colsample_bytree': uniform(0.6, 0.4), # Random float values between 0.6 and 1.0
    'reg_alpha': uniform(0, 0.5),      # L1 regularization term
    'reg_lambda': uniform(0,  0.5)   # L2 regularization term
}

# Creating an instance of XGBRegressor 
xgb_model = xgb.XGBRegressor()  

# Creating a RandomizedSearchCV object
random_search = RandomizedSearchCV(xgb_model, param_distributions=param_grid, n_iter=10, cv=5, scoring='accuracy', random_state=random_seed)

# Fitting the RandomizedSearchCV object to the data
random_search.fit(X_train, y_train)

# Getting the best hyperparameters
best_params = random_search.best_params_
# Out:
# C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:770: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 761, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 216, in __call__
#     return self._score(
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_scorer.py", line 264, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 211, in accuracy_score
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "C:\Users\User\anaconda3\lib\site-packages\sklearn\metrics\_classification.py", line 104, in _check_targets
#     raise ValueError("{0} is not supported".format(y_type))
# ValueError: continuous is not supported
#
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:969: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(

# %%
best_estimator = random_search.best_estimator_

# %%
best_estimator
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.749816047538945, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.2952142919229748,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=171, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
best_params
# Out:
# {'colsample_bytree': 0.749816047538945,
#  'learning_rate': 0.2952142919229748,
#  'max_depth': 5,
#  'n_estimators': 171,
#  'reg_alpha': 0.2993292420985183,
#  'reg_lambda': 0.07800932022121826,
#  'subsample': 0.662397808134481}

# %%
# Training the model with the best hyperparameters
xgb_best = xgb.XGBRegressor(**best_params)  
xgb_best.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.749816047538945, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.2952142919229748,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=171, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
## Cross Validation of Model

Score=cross_val_score(xgb_best,X_train,y_train,cv=10)

# %%
Score
# Out:
# array([0.99155215, 0.99159671, 0.9900644 , 0.99195808, 0.9917074 ,
#        0.9911383 , 0.99066303, 0.99099801, 0.9906945 , 0.99193281])

# %%
Score
Score.mean()
# Out:
# 0.9912305383430636

# %%
#model prediction
y_pred5 = xgb_best.predict(X_test)


#XGB Boost Evaluation
mse_4 = mean_squared_error(y_test, y_pred5)
rmse_4 = np.sqrt(mse_4)
r2_4 = r2_score(y_test, y_pred5)
mae_4 = mean_absolute_error(y_test, y_pred5)
print("Xgb Boost MAE:", mae_4)
print("Xgb Boost R-squared:", r2_4)
print("Xgb Boost RMSE:", rmse_4)
print("Xgb Boost MSE:", mse_4)
# Out:
# Xgb Boost MAE: 1.1277616763372291
# Xgb Boost R-squared: 0.9926065044755998
# Xgb Boost RMSE: 1.5104463467708535
# Xgb Boost MSE: 2.281448166473418

# %%
# Setting the random seed for reproducibility
random_seed = 42
np.random.seed(random_seed)

# Defining the parameter grid
param_grid = {
    'n_estimators': randint(100, 1000),  # Random integer values between 100 and 1000
    'learning_rate': uniform(0.01, 0.3),  # Random float values between 0.01 and 0.3
    'max_depth': randint(3, 10),  # Random integer values between 3 and 10
    'subsample': uniform(0.6, 0.4),  # Random float values between 0.6 and 1.0
    'max_features': ['auto', 'sqrt'], # Randomly selects between 'auto' and 'sqrt'
    'min_samples_leaf': randint(1, 5),  # Random integer values between 1 and 5 (Regularization term)
}

# Creating an instance of the GradientBoostingRegressor
gb_model = GradientBoostingRegressor()

# Creating a RandomizedSearchCV object with random_state set to the random seed
random_search = RandomizedSearchCV(gb_model, param_distributions=param_grid, n_iter=10, cv=5, scoring='neg_mean_squared_error', random_state=random_seed)

# Fitting the RandomizedSearchCV object to the data
random_search.fit(X_train, y_train)

# Getting the best hyperparameters
best_params1 = random_search.best_params_

# %%
best_params1
# Out:
# {'learning_rate': 0.0792681476866447,
#  'max_depth': 6,
#  'max_features': 'auto',
#  'min_samples_leaf': 4,
#  'n_estimators': 554,
#  'subsample': 0.8439986631130484}

# %%
# Training the model with the best hyperparameters
gb_best1 = GradientBoostingRegressor(**best_params1)
gb_best1.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(learning_rate=0.0792681476866447, max_depth=6,
#                           max_features='auto', min_samples_leaf=4,
#                           n_estimators=554, subsample=0.8439986631130484)

# %%
## Cross Validation of Model

Score=cross_val_score(gb_best1,X_train,y_train,cv=10)
Score
Score.mean()
# Out:
# 0.9971255192245077

# %%
# Predicting on the test set
y_pred2 = gb_best1.predict(X_test)

#Gradient Boost Evaluation
mse_2 = mean_squared_error(y_test, y_pred2)
rmse_2 = np.sqrt(mse_2)
r2_2 = r2_score(y_test, y_pred2)
mae_2 = mean_absolute_error(y_test, y_pred2)
print("Gradient Boost MAE:", mae_2)
print("Gradient Boost R-squared:", r2_2)
print("Gradient Boost RMSE:", rmse_2)
print("Gradient Boost MSE:", mse_2)
# Out:
# Gradient Boost MAE: 0.6125885587747808
# Gradient Boost R-squared: 0.9971925658558758
# Gradient Boost RMSE: 0.9307545859432698
# Gradient Boost MSE: 0.8663040992544275

# %%
# Setting the random seed for reproducibility
random_seed = 42
np.random.seed(random_seed)

# Defining the parameter grid
param_grid = {
    'n_estimators': randint(100, 1000),  # Random integer values between 100 and 1000
    'max_features': ['auto', 'sqrt'],  # Randomly selects between 'auto' and 'sqrt'
    'max_depth': randint(3, 10),  # Random integer values between 3 and 10
    'min_samples_split': randint(2, 10),  # Random integer values between 2 and 10
    'min_samples_leaf': randint(1, 5),  # Random integer values between 1 and 5 (Regularization term)
    'bootstrap': [True, False]  # Randomly selects between True and False
}

# Creating an instance of the Random Forest regressor
rf_model = RandomForestRegressor()

# Creating a RandomizedSearchCV object with random_state set to the random seed
random_search = RandomizedSearchCV(rf_model, param_distributions=param_grid, n_iter=10, cv=5, scoring='neg_mean_squared_error', random_state=random_seed)

# Fitting the RandomizedSearchCV object to the data
random_search.fit(X_train, y_train)

# Getting the best hyperparameters
best_params_rf = random_search.best_params_

# %%
best_params_rf
# Out:
# {'bootstrap': True,
#  'max_depth': 7,
#  'max_features': 'auto',
#  'min_samples_leaf': 2,
#  'min_samples_split': 4,
#  'n_estimators': 314}

# %%
# Training the model with the best hyperparameters
rf_best = RandomForestRegressor(**best_params_rf)
rf_best.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=7, min_samples_leaf=2, min_samples_split=4,
#                       n_estimators=314)

# %%
## Cross Validation of Model

Score=cross_val_score(rf_best,X_train,y_train,cv=10)
Score
Score.mean()
# Out:
# 0.9259934751889073

# %%
y_pred = rf_best.predict(X_test)

#Random Forest Evaluation
mse_1 = mean_squared_error(y_test, y_pred)
rmse_1 = np.sqrt(mse_1)
r2_1 = r2_score(y_test, y_pred)
mae_1 = mean_absolute_error(y_test, y_pred)
print("RF MAE:", mae_1)
print("RF R-squared:", r2_1)
print("RF RMSE:", rmse_1)
print("RF MSE:", mse_1)
# Out:
# RF MAE: 3.4641584912423045
# RF R-squared: 0.9240364445249816
# RF RMSE: 4.841534576890486
# RF MSE: 23.440457059226134

# %%
# Setting the random seed for reproducibility
random_seed = 42
np.random.seed(random_seed)

# Defining the parameter grid
param_grid = {
    'base_estimator': [DecisionTreeRegressor(max_depth=d, random_state=random_seed) for d in range(3, 10)],  # Vary max_depth of Decision Tree(Regularistion term)
    'n_estimators': randint(100, 1000),  # Random integer values between 100 and 1000
    'learning_rate': uniform(0.01, 0.3)  # Random float values between 0.01 and 0.3
}

# Creating an instance of the AdaBoostRegressor
adaboost_model = AdaBoostRegressor(random_state=random_seed)

# Creating a RandomizedSearchCV object with random_state set to the random seed
random_search = RandomizedSearchCV(adaboost_model, param_distributions=param_grid, n_iter=10, cv=5, scoring='neg_mean_squared_error', random_state=random_seed)

# Fitting the RandomizedSearchCV object to the data
random_search.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=AdaBoostRegressor(random_state=42),
#                    param_distributions={'base_estimator': [DecisionTreeRegressor(max_depth=3,
#                                                                                  random_state=42),
#                                                            DecisionTreeRegressor(max_depth=4,
#                                                                                  random_state=42),
#                                                            DecisionTreeRegressor(max_depth=5,
#                                                                                  random_state=42),
#                                                            DecisionTreeRegressor(max_depth=6,
#                                                                                  random_state=42),
#                                                            DecisionTreeRegressor(max_depth=7,
#                                                                                  random_state=42),
#                                                            DecisionTreeRegressor(max_depth=8,
#                                                                                  random_state=42),
#                                                            DecisionTreeRegressor(max_depth=9,
#                                                                                  random_state=42)],
#                                         'learning_rate': <scipy.stats._distn_infrastructure.rv_frozen object at 0x000002844EA984C0>,
#                                         'n_estimators': <scipy.stats._distn_infrastructure.rv_frozen object at 0x000002844EA87E80>},
#                    random_state=42, scoring='neg_mean_squared_error')

# %%
# Getting the best hyperparameters
best_params_ada = random_search.best_params_

# %%
best_params_ada
# Out:
# {'base_estimator': DecisionTreeRegressor(max_depth=9, random_state=42),
#  'learning_rate': 0.24896289605806984,
#  'n_estimators': 370}

# %%
# Training the model with the best hyperparameters
adaboost_best = AdaBoostRegressor(**best_params_ada)
adaboost_best.fit(X_train, y_train)
# Out:
# AdaBoostRegressor(base_estimator=DecisionTreeRegressor(max_depth=9,
#                                                        random_state=42),
#                   learning_rate=0.24896289605806984, n_estimators=370)

# %%
## Cross Validation of Model
Score=cross_val_score(adaboost_best,X_train,y_train,cv=10)
Score
Score.mean()
# Out:
# 0.9914210726632147

# %%
# Predicting on the test set
y_pred1 = adaboost_best.predict(X_test)
                       
#Adaptive Boost Evaluation
mse_3 = mean_squared_error(y_test, y_pred1)
rmse_3 = np.sqrt(mse_3)
r2_3 = r2_score(y_test, y_pred1)
mae_3 = mean_absolute_error(y_test, y_pred1)
print("ADA Boost MAE:", mae_3)
print("ADA Boost R-squared:", r2_3)
print("ADA Boost RMSE:", rmse_3)
print("ADA Boost MSE:", mse_3)
# Out:
# ADA Boost MAE: 1.2405498307441836
# ADA Boost R-squared: 0.9916172763076212
# ADA Boost RMSE: 1.6083218852405883
# ADA Boost MSE: 2.58669928654384

# %%
def plot_metrics(mse_values, rmse_values, r2_values, mae_values, model_names, output_dir):
    # Creating DataFrames for each metric
    MSE = pd.DataFrame({model_names[i]: mse_values[i] for i in range(len(model_names))}, index=['MSE'])
    RMSE = pd.DataFrame({model_names[i]: rmse_values[i] for i in range(len(model_names))}, index=['RMSE'])
    R2 = pd.DataFrame({model_names[i]: r2_values[i] for i in range(len(model_names))}, index=['R2'])
    MAE = pd.DataFrame({model_names[i]: mae_values[i] for i in range(len(model_names))}, index=['MAE'])

    # Plotting the bar charts for each metric
    fig, axes = plt.subplots(2, 2, figsize=(15, 15))
    sns.barplot(data=MSE, ax=axes[0, 0])
    axes[0, 0].set(xlabel='Model', ylabel='MSE')
    axes[0, 0].set_title('Mean Square Error (MSE) by Models for Uma Scenario')

    sns.barplot(data=RMSE, ax=axes[0, 1])
    axes[0, 1].set(xlabel='Model', ylabel='RMSE')
    axes[0, 1].set_title('Root Mean Square Error (RMSE) by Models for Uma Scenario')

    sns.barplot(data=R2, ax=axes[1, 0])
    axes[1, 0].set(xlabel='Model', ylabel='R2')
    axes[1, 0].set_title('R2 (R2) by Models for Uma Scenario')

    sns.barplot(data=MAE, ax=axes[1, 1])
    axes[1, 1].set(xlabel='Model', ylabel='MAE')
    axes[1, 1].set_title('Mean Square Error (MAE) by Models for Uma Scenario')

    plt.tight_layout()
    plt.show()

    # Creating the output directory 
    os.makedirs(output_dir, exist_ok=True)

    # Saving the figures as JPEG image files
    fig.savefig(f'{output_dir}/metrics_plot.jpg')
    plt.close()

# the MSE, RMSE, R2, and MAE values for each model 
mse_values = [mse_1, mse_2, mse_3, mse_4, mse_5]
rmse_values = [rmse_1, rmse_2, rmse_3, rmse_4, rmse_5]
r2_values = [r2_1, r2_2, r2_3, r2_4, r2_5]
mae_values = [mae_1, mae_2, mae_3, mae_4, mae_5]
model_names = ['Random Forest', 'Gradient Boost', 'Ada Boost', 'Xgb Boost', 'Dummy Regressor']
output_dir = 'New folder'  

plot_metrics(mse_values, rmse_values, r2_values, mae_values, model_names, output_dir)

# %%
def plot_learning_curve(model, X_train, y_train, cv=5, model_name=None, ax=None):
    # Defining the training set sizes for the learning curve
    train_sizes, train_scores, test_scores = learning_curve(
        model, X_train, y_train, cv=cv, train_sizes=np.linspace(0.1, 1.0, 10), scoring='neg_mean_squared_error'
    )

    # Calculating the mean and standard deviation of training and test scores
    train_mean = -np.mean(train_scores, axis=1)
    train_std = np.std(train_scores, axis=1)
    test_mean = -np.mean(test_scores, axis=1)
    test_std = np.std(test_scores, axis=1)

    # Plotting the learning curve on the provided axis
    ax.plot(train_sizes, np.sqrt(train_mean), label='Training RMSE', color='blue')
    ax.plot(train_sizes, np.sqrt(test_mean), label='Validation RMSE', color='red')

    # Adding standard deviation regions
    ax.fill_between(train_sizes, np.sqrt(train_mean - train_std), np.sqrt(train_mean + train_std), color='blue', alpha=0.1)
    ax.fill_between(train_sizes, np.sqrt(test_mean - test_std), np.sqrt(test_mean + test_std), color='red', alpha=0.1)

    # Adding model name as annotation
    last_train_mean = np.sqrt(train_mean[-1])
    last_test_mean = np.sqrt(test_mean[-1])
    ax.annotate(model_name, xy=(train_sizes[-1], last_train_mean), xytext=(-20, -10),
                textcoords='offset points', ha='right', va='center', color='blue', weight='bold')
    ax.annotate(model_name, xy=(train_sizes[-1], last_test_mean), xytext=(-20, 10),
                textcoords='offset points', ha='right', va='center', color='red', weight='bold')

def save_learning_curve_plot(models, X_train, y_train, output_dir):
    # Creating a single figure to combine all learning curve plots
    plt.figure(figsize=(12, 8))

    # Creating a single subplot for the learning curve
    ax = plt.subplot(1, 1, 1)
    for model, model_name in models:
        plot_learning_curve(model, X_train, y_train, model_name=model_name, ax=ax)

    # Adding labels, title, and legend to the figure
    plt.xlabel('Training Set Size')
    plt.ylabel('Root Mean Squared Error (RMSE)')
    plt.title('Learning Curves for Different Models in Uma Scenario')
    plt.legend(loc='best')

    # Saving the figure as JPEG
    plt.savefig(f'{output_dir}/learning_curves.jpg', format='jpeg')

    # Displaying the plot
    plt.tight_layout()
    plt.show()


#  displaying the learning curve plot
output_dir = 'New folder1'  
models = [(rf_best, 'Random Forest'),
          (xgb_best, 'XGBoost'),
          (adaboost_best, 'AdaBoost'),
          (gb_best1, 'Gradient Boost')]
save_learning_curve_plot(models, X_train, y_train, output_dir)

# %%
# Reading data from Excel file
df = pd.read_excel('Umascenario.xlsx')

# Extracting the three features from the DataFrame
T_R_values = df['T-R Separation Distance (m)']
Path_Loss_values = df['Path Loss (dB)']
Frequency_values = df['frequency']

# Creating a grid-like scatter plot
plt.scatter(T_R_values, Path_Loss_values, c=Frequency_values, cmap='viridis')

# Adding labels and title
plt.xlabel('T-R Separation Distance (m)')
plt.ylabel('Path Loss (dB)')
plt.title('Path Loss vs T-R Separation Distance with frequency in Uma Scenario')

# Adding colorbar
cbar = plt.colorbar()
cbar.set_label('frequency')

# Saving the plot as JPEG
plt.savefig('plot2.jpg')

# %%
import matplotlib.pyplot as plt

# Defining the values and labels
values = [6.27, 8.67, 5.60, 6.67, 4.98, 0.93]
labels = [
    "Adetiba et al., 2018",
    "Ali et al., 2018",
    "Sotiroudis, Goudos and Siakavara, 2019",
    "Aldossari and Chen, 2020",
    "Chowdhury et al., 2023",
    "This Study (Gradient Boosting Regressor)"
]

plt.figure(figsize=(10, 8))  

# Creating the bar chart
plt.bar(labels, values)

# Adding labels and title
plt.xlabel('Research Articles', fontsize=12)
plt.ylabel('RMSE', fontsize=12)
plt.title('Comparison of RMSE performance with contemporary articles', fontsize=10)

# Setting the rotation and alignment of x-axis tick labels
plt.xticks(rotation=45, ha='right')

# Adjusting the spacing between subplots to make x-axis lettering visible
plt.tight_layout()

#Saving the chart as a JPEG file
plt.savefig('bar_chart.jpg')
